# %%
masks_folder = '/home/miguel/GI/1.5 - Synthetic Data Generation/diffuse-gen/diffuse-gen/guided_diffusion/segmented-images-roberta-aug/FD-027/masks'

# %%
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
for file in os.listdir(masks_folder):
    path = os.path.join(masks_folder, file)
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    if mask.sum() < 100000:
        plt.imshow(mask)
        plt.show()
        break

# %%
mask.sum()
# Out:
# 3433883

# %%
plt.imshow(mask)
